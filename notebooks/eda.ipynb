# %% [markdown]
# ### đọc dữ liệu

# %%
import pandas as pd

df = pd.read_csv(r"D:\PRO2291_DuAnTopNghiep\PRO2291_duantotnghiep1\data\raw/sales_06_FY2020-21.csv")

df.head()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_20640\3516725256.py:3: DtypeWarning: Columns (0: order_id) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"D:\PRO2291_DuAnTopNghiep\PRO2291_duantotnghiep1\data\raw/sales_06_FY2020-21.csv")
#     order_id  order_date    status  item_id                  sku  qty_ordered  \
# 0  100354678   10/1/2020  received   574772   oasis_Oasis-064-36           21
# 1  100354678   10/1/2020  received   574774      Fantastic_FT-48           11
# 2  100354680   10/1/2020  complete   574777      mdeal_DMC-610-8            9
# 3  100354680   10/1/2020  complete   574779   oasis_Oasis-061-36            9
# 4  100367357  11/13/2020  received   595185  MEFNAR59C38B6CA08CD            2
#
#    price   value  discount_amount   total  ...          SSN    Phone No.   \
# 0   89.9  1798.0              0.0  1798.0  ...  627-31-5251  405-959-1129
# 1   19.0   190.0              0.0   190.0  ...  627-31-5251  405-959-1129
# ...

# %% [markdown]
# # Kiểm tra kiểu dữ liệu

# %%
df.info() #Kiểm tra kiểu dữ liệu
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 286392 entries, 0 to 286391
# Data columns (total 36 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   order_id          286392 non-null  object
#  1   order_date        286392 non-null  str
#  2   status            286392 non-null  str
#  3   item_id           286392 non-null  int64
#  4   sku               286392 non-null  str
#  5   qty_ordered       286392 non-null  int64
#  6   price             286392 non-null  float64
#  7   value             286392 non-null  float64
#  8   discount_amount   286392 non-null  float64
#  9   total             286392 non-null  float64
#  10  category          286392 non-null  str
#  11  payment_method    286392 non-null  str
#  12  bi_st             286392 non-null  str
#  13  cust_id           286392 non-null  int64
#  14  year              286392 non-null  int64
#  15  month             286392 non-null  str
# ...

# %%
df.isnull().sum() #Kiểm tra null
# Out:
# order_id            0
# order_date          0
# status              0
# item_id             0
# sku                 0
# qty_ordered         0
# price               0
# value               0
# discount_amount     0
# total               0
# category            0
# payment_method      0
# bi_st               0
# cust_id             0
# year                0
# month               0
# ref_num             0
# Name Prefix         0
# First Name          0
# Middle Initial      0
# Last Name           0
# Gender              0
# age                 0
# full_name           0
# E Mail              0
# Customer Since      0
# SSN                 0
# Phone No.           0
# Place Name          0
# County              0
# City                0
# State               0
# Zip                 0
# Region              0
# User Name           0
# Discount_Percent    0
# dtype: int64

# %%
df.duplicated().sum() #Kiểm tra duplicate
# Out:
# np.int64(0)

# %%
df.describe() #Thống kê
# Out:
#              item_id    qty_ordered          price          value  \
# count  286392.000000  286392.000000  286392.000000  286392.000000
# mean   741664.902131       3.011296     851.385253     885.879934
# std     95746.031827       4.573837    1741.750751    2073.252179
# min    574769.000000       1.000000       0.000000       0.000000
# 25%    659684.500000       2.000000      49.900000      49.900000
# 50%    742309.000000       2.000000     119.000000     158.970000
# 75%    826124.250000       3.000000     950.000000     910.000000
# max    905208.000000     501.000000  101262.590000  101262.590000
#
#        discount_amount          total        cust_id           year  \
# count    286392.000000  286392.000000  286392.000000  286392.000000
# mean         70.039427     815.840507   70048.019054    2020.618778
# std         256.880870    1983.580302   30243.856395       0.485688
# min           0.000000       0.000000       4.000000    2020.000000
# ...
